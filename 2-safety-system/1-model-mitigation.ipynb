# %% [markdown]
# ### Load environment variables

# %%
from dotenv import load_dotenv
import os
load_dotenv('../.env')
# Out:
# True

# %% [markdown]
# ### Define AI Studio connection

# %%
# define the Azure AI Studio connection
azure_ai_project = {
    "subscription_id": os.environ.get("SUBSCRIPTION_ID"),
    "resource_group_name": os.environ.get("RESOURCE_GROUP_NAME"),
    "project_name": os.environ.get("PROJECT_NAME"),
    #"credential": token_provider,
}

# %% [markdown]
# ### Load the dataset

# %%
import json
def load_jsonl(path):
    with open(path, "r") as f:
        return [json.loads(line) for line in f.readlines()]
    
mydata = load_jsonl('../data/evaluation_dataset.jsonl')

# %%
# create directory for output
output_dir = '../data/evaluate/aoai/'
os.makedirs(output_dir, exist_ok=True)

# %% [markdown]
# ### Evaluate Azure OpenAI using RAG (index created in setup)

# %%
#from azure.ai.generative.evaluate import evaluate
from promptflow.evals.evaluate import evaluate

result = evaluate( 
    evaluation_name="azure-openai-qa-eval", #name your evaluation to view in AI Studio
    data=mydata, # data to be evaluated
    task_type="qa", # for different task types, different metrics are available
    metrics_list=["gpt_groundedness", "gpt_relevance", "gpt_coherence", "gpt_fluency", "gpt_similarity"], #optional superset over default set of metrics
    model_config= { #for AI-assisted metrics, need to hook up AOAI GPT model for doing the measurement
            "api_version": "2023-05-15",
            "api_base": os.getenv("AZURE_OPENAI_ENDPOINT"),
            "api_type": "azure",
            "api_key": os.getenv("AZURE_OPENAI_KEY"),
            "deployment_id": os.getenv("AZURE_OPENAI_EVALUATION_DEPLOYMENT")
    },
    data_mapping={
        "questions":"question", #column of data providing input to model
        "contexts":"context", #column of data providing context for each input
        "answer":"answer", #column of data providing output from model
        "ground_truth":"groundtruth" #column of data providing ground truth answer, optional for default metrics
        },
    # Optionally provide your AI Studio project information to track your evaluation results in your Azure AI studio project
    azure_ai_project = azure_ai_project,
    # Optionally provide an output path to dump a json of metric summary, row level data and metric and studio URL
    output_path=output_dir
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 4
#       1 #from azure.ai.generative.evaluate import evaluate
#       2 from promptflow.evals.evaluate import evaluate
# ----> 4 result = evaluate(
#       5     evaluation_name="azure-openai-qa-eval", #name your evaluation to view in AI Studio
#       6     data=mydata, # data to be evaluated
#       7     task_type="qa", # for different task types, different metrics are available
#       8     metrics_list=["gpt_groundedness", "gpt_relevance", "gpt_coherence", "gpt_fluency", "gpt_similarity"], #optional superset over default set of metrics
#       9     model_config= { #for AI-assisted metrics, need to hook up AOAI GPT model for doing the measurement
#      10             "api_version": "2023-05-15",
#      11             "api_base": os.getenv("AZURE_OPENAI_ENDPOINT"),
#      12             "api_type": "azure",
#      13             "api_key": os.getenv("AZURE_OPENAI_KEY"),
#      14             "deployment_id": os.getenv("AZURE_OPENAI_EVALUATION_DEPLOYMENT")
#      15     },
#      16     data_mapping={
#      17         "questions":"question", #column of data providing input to model
#      18         "contexts":"context", #column of data providing context for each input
#      19         "answer":"answer", #column of data providing output from model
#      20         "ground_truth":"groundtruth" #column of data providing ground truth answer, optional for default metrics
#      21         },
#      22     # Optionally provide your AI Studio project information to track your evaluation results in your Azure AI studio project
#      23     azure_ai_project = azure_ai_project,
#      24     # Optionally provide an output path to dump a json of metric summary, row level data and metric and studio URL
#      25     output_path=output_dir
#      26 )
#
# File ~/miniconda3/envs/pf-eval/lib/python3.12/site-packages/promptflow/evals/evaluate/_telemetry/__init__.py:138, in log_evaluate_activity.<locals>.wrapper(*args, **kwargs)
#     125 custom_dimensions = {
#     126     "track_in_cloud": track_in_cloud,
#     127     "evaluate_target": evaluate_target,
#     128     "evaluator_config": evaluator_config,
#     129 }
#     131 with log_activity(
#     132     get_telemetry_logger(),
#     133     "pf.evals.evaluate",
#    (...)
#     136     custom_dimensions=custom_dimensions,
#     137 ):
# --> 138     result = func(*args, **kwargs)
#     140     try:
#     141         evaluators_info = []
#
# File ~/miniconda3/envs/pf-eval/lib/python3.12/site-packages/promptflow/evals/evaluate/_evaluate.py:381, in evaluate(evaluation_name, target, data, evaluators, evaluator_config, azure_ai_project, output_path, **kwargs)
#     373     error_message = (
#     374         "The evaluation failed due to an error during multiprocess bootstrapping."
#     375         "Please ensure the evaluate API is properly guarded with the '__main__' block:\n\n"
#     376         "    if __name__ == '__main__':\n"
#     377         "        evaluate(...)"
#     378     )
#     379     raise RuntimeError(error_message) from e
# --> 381 raise e
#
# File ~/miniconda3/envs/pf-eval/lib/python3.12/site-packages/promptflow/evals/evaluate/_evaluate.py:356, in evaluate(evaluation_name, target, data, evaluators, evaluator_config, azure_ai_project, output_path, **kwargs)
#     288 """Evaluates target or data with built-in or custom evaluators. If both target and data are provided,
#     289     data will be run through target function and then results will be evaluated.
#     290
#    (...)
#     353
#     354 """
#     355 try:
# --> 356     return _evaluate(
#     357         evaluation_name=evaluation_name,
#     358         target=target,
#     359         data=data,
#     360         evaluators=evaluators,
#     361         evaluator_config=evaluator_config,
#     362         azure_ai_project=azure_ai_project,
#     363         output_path=output_path,
#     364         **kwargs,
#     365     )
#     366 except Exception as e:
#     367     # Handle multiprocess bootstrap error
#     368     bootstrap_error = (
#     369         "An attempt has been made to start a new process before the\n        "
#     370         "current process has finished its bootstrapping phase."
#     371     )
#
# File ~/miniconda3/envs/pf-eval/lib/python3.12/site-packages/promptflow/evals/evaluate/_evaluate.py:395, in _evaluate(evaluation_name, target, data, evaluators, evaluator_config, azure_ai_project, output_path, **kwargs)
#     384 def _evaluate(  # pylint: disable=too-many-locals
#     385     *,
#     386     evaluation_name: Optional[str] = None,
#    (...)
#     393     **kwargs,
#     394 ):
# --> 395     input_data_df = _validate_and_load_data(target, data, evaluators, output_path, azure_ai_project, evaluation_name)
#     397     # Process evaluator config to replace ${target.} with ${data.}
#     398     if evaluator_config is None:
#
# File ~/miniconda3/envs/pf-eval/lib/python3.12/site-packages/promptflow/evals/evaluate/_evaluate.py:96, in _validate_and_load_data(target, data, evaluators, output_path, azure_ai_project, evaluation_name)
#      94 if data is not None:
#      95     if not isinstance(data, str):
# ---> 96         raise ValueError("data must be a string.")
#      98 if evaluators is not None:
#      99     if not isinstance(evaluators, dict):
#
# ValueError: data must be a string.

# %%
from promptflow.evals.evaluate import evaluate

result = evaluate(
    evaluation_name="rai-workshop-test", #name your evaluation to view in AI Studio
    data=mydata, # provide your data here - must be string
    target=llm_tool,
    evaluators={
        #"relevance": relevance_eval,
        "coherence": coherence_eval,
        #"groundedness": groundedness_eval,
        "fluency": fluency_eval,
        "similarity": similarity_eval,
        "f1_score": f1score_eval

    },
    # column mapping
    evaluator_config={
        "default": {
            "question": "${data.question)", #column of data providing input to model
            #"contexts": "${data.context}", #column of data providing context for each input
            "answer": "${target.answer}", #column of data providing output from model
            "ground_truth":"${data.truth}" #column of data providing ground truth answer, optional for default metrics
        }
    },
    # Optionally provide your AI Studio project information to track your evaluation results in your Azure AI studio project
    azure_ai_project = azure_ai_project,
    # Optionally provide an output path to dump a json of metric summary, row level data and metric and studio URL
    output_path=output_dir
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 6
#       1 from promptflow.evals.evaluate import evaluate
#       3 result = evaluate(
#       4     evaluation_name="rai-workshop-test", #name your evaluation to view in AI Studio
#       5     data=mydata, # provide your data here - must be string
# ----> 6     target=llm_tool,
#       7     evaluators={
#       8         #"relevance": relevance_eval,
#       9         "coherence": coherence_eval,
#      10         #"groundedness": groundedness_eval,
#      11         "fluency": fluency_eval,
#      12         "similarity": similarity_eval,
#      13         "f1_score": f1score_eval
#      14
#      15     },
#      16     # column mapping
#      17     evaluator_config={
#      18         "default": {
#      19             "question": "${data.question)", #column of data providing input to model
#      20             #"contexts": "${data.context}", #column of data providing context for each input
#      21             "answer": "${target.answer}", #column of data providing output from model
#      22             "ground_truth":"${data.truth}" #column of data providing ground truth answer, optional for default metrics
#      23         }
#      24     },
#      25     # Optionally provide your AI Studio project information to track your evaluation results in your Azure AI studio project
#      26     azure_ai_project = azure_ai_project,
#      27     # Optionally provide an output path to dump a json of metric summary, row level data and metric and studio URL
#      28     output_path=output_dir
#      29 )
#
# NameError: name 'llm_tool' is not defined

# %%
# Show average results
print(result._metrics_summary)
# Out:
# {'gpt_coherence': 5.0, 'gpt_similarity': nan, 'gpt_fluency': 5.0, 'gpt_relevance': 5.0, 'gpt_groundedness': 5.0}

# %%
print(result.studio_url)
# Out:
# https://ai.azure.com/build/evaluation/13d44513-6a55-4f4b-ae9e-926284ed93d3?wsid=/subscriptions/3c8972d9-f541-46b2-b70b-d81baba3595d/resourceGroups/aistudio-rg/providers/Microsoft.MachineLearningServices/workspaces/aistudio-ai-aiproj

# %% [markdown]
# ### Repeat, but this time with another model

# %%
from azure.ai.generative.evaluate import evaluate

result = evaluate( 
    evaluation_name="azure-phi2-qa-eval", #name your evaluation to view in AI Studio
    data=mydata, # data to be evaluated
    task_type="qa", # for different task types, different metrics are available
    metrics_list=["gpt_groundedness", "gpt_relevance", "gpt_coherence", "gpt_fluency", "gpt_similarity"], #optional superset over default set of metrics
    model_config= { #for AI-assisted metrics, need to hook up AOAI GPT model for doing the measurement
            "api_version": "2023-05-15",
            "api_base": os.getenv("AZURE_OPENAI_ENDPOINT"),
            "api_type": "azure",
            "api_key": os.getenv("AZURE_OPENAI_KEY"),
            "deployment_id": os.getenv("AZURE_OPENAI_EVALUATION_DEPLOYMENT")
    },
    data_mapping={
        "questions":"question", #column of data providing input to model
        "contexts":"context", #column of data providing context for each input
        "answer":"answer", #column of data providing output from model
        "ground_truth":"groundtruth" #column of data providing ground truth answer, optional for default metrics
        },
        output_path=output_dir, #optional: save output artifacts to local folder path 
    tracking_uri=client.tracking_uri, #optional: if configured with AI client, evaluation gets logged to AI Studio   
)
